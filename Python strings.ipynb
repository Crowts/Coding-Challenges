# %% [markdown]
# ## <font color=blue> Challenge</font>
#
# Find the characters in the string below that do not belong to the list ['1','2','3','4','5']. Join these 'outsiders' to form a string.

# %% [markdown]
# ## <font color=blue> Solution</font>

# %%
some_string = '...'
string_list = ['1','2','3','4','5']
sol = []
for i in some_string:
    if i not in string_list:
        sol.append(i)
Y = ''
for j in sol:
    Y += j
Y
# Out:
# 'S0S'
